# %% [markdown]
# The aim of this notebook is to train a simple GAN architecture, detect mode collapse, and compute NDB score to quantify mode collapse

# %%
#Importing Libraries
import numpy as np
import pandas as pd
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
np.random.seed(42)
import random
import math
import numpy as np
import matplotlib.pyplot as plt
import tensorflow  as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Reshape, UpSampling2D, Conv2D, BatchNormalization, Input
from tensorflow.keras.layers import LeakyReLU, Dropout, ZeroPadding2D, Flatten, Activation
from tensorflow.keras.optimizers import Adam
import tqdm
import cv2

# %% [markdown]
# # Config

# %%
class config:
    img_dir = "../input/art-portraits/Portraits/"
    batch_size = 32
    img_size = 64
    latent_dim = 100
    dropout = 0.2
    """
    arch : [filters,kernel_size,strides,padding,activation]
    """
    discrim_arch = [
    [32,3,2,'same'],
    [64,3,2,'same'],
    [128,3,2,'same'],
    [256,3,1,'same'],
    [512,3,1,'same']
]
    """
    arch : [reshape_size,activation]
    """
    reshape_layer = [(4,4,256),'relu']
    
    """
    arch : [filters,kernel_size,padding,activation]
    """
    
    generator_arch = [
    [256,3,'same'],
    [256,3,'same'],
    [256,3,'same'],
    [128,3,'same'],
    [3,3,'same']
]
    epochs = 150
    discriminator_lr = 1e-5
    generator_lr = 1e-5
    beta = 0.5

# %% [markdown]
# # Preprocessing

# %% [markdown]
# I've randomly plotted some images. The images vary in size, so I'll shrink them down to (64,64) to speed up model training.

# %%
print(f"Number of images = {len(os.listdir(config.img_dir))}")
# Out:
# Number of images = 4117

# %%
f,ax = plt.subplots(2,3,figsize=(15,8))
ax = ax.flatten()
for i,img_name in enumerate(os.listdir(config.img_dir)[100:106]):
    img = cv2.imread(f"{config.img_dir}/{img_name}",-1)
    ax[i].imshow(img)
    ax[i].set_title(f"img_shape:{img.shape}")

# %%
#Import as tf.Dataset
portraits = tf.keras.preprocessing.image_dataset_from_directory(config.img_dir,label_mode=None ,image_size=(config.img_size,config.img_size), batch_size=config.batch_size).map(lambda x: x / 255.0)
# Out:
# Found 4117 files belonging to 1 classes.

# %%
#Plotting reshape images from the keras dataset
plt.figure(figsize=(15,15))
for image_batch in portraits.take(1):
    for i in range(18):
        ax = plt.subplot(6, 6, i + 1)
        ax.imshow(image_batch[i].numpy())

# %% [markdown]
# # Generator
#
# The generator accepts a random 1D array (I've chosen a length of 100). The first dense layer expands the input and the subsequent reshape layer transforms it to a 3D tensor. Next, the tensor goes down a fully convolutional network, made up of multiple convup_blocks, which produce an rgb image of size specified in config (I've taken 64). All convup_blocks, instead of the last one, consist of a convolutional layer and an upsampling layer. As the name suggests, the upsampling layer the doubles the dimensions of the input. However, unlike the transpose convolutional layer, its parameters are not learnable.

# %%
#Convup_block which includes a convolutional layer and an upsample
def convup_block(mod,activation=Activation('relu'),last=False,**kwargs):
    mod.add(Conv2D(**kwargs))
    if last==False:
        mod.add(BatchNormalization())
        mod.add(activation)
        mod.add(UpSampling2D())
    else:
        mod.add(activation)
    return mod

# %%
# Building the Generator
generator = Sequential()
generator.add(Dense(np.product(config.reshape_layer[0]),activation=config.reshape_layer[1],input_dim=config.latent_dim))
generator.add(Reshape(config.reshape_layer[0]))
for i in range(len(config.generator_arch)):
    layer = config.generator_arch[i]
    dic = {'filters': layer[0], 'kernel_size': layer[1], 
           'padding': layer[2]}
    if i == len(config.generator_arch)-1:
        generator = convup_block(generator,activation=Activation('sigmoid'),last=True,**dic)
    else:
        generator = convup_block(generator,activation=Activation('relu'),**dic)
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 4096)              413696
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 4, 4, 256)         590080
# _________________________________________________________________
# batch_normalization (BatchNo (None, 4, 4, 256)         1024
# _________________________________________________________________
# activation_1 (Activation)    (None, 4, 4, 256)         0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 256)       0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       295040
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# activation_4 (Activation)    (None, 32, 32, 128)       0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 3)         3459
# _________________________________________________________________
# activation_5 (Activation)    (None, 64, 64, 3)         0
# =================================================================
# Total params: 2,486,019
# Trainable params: 2,484,227
# Non-trainable params: 1,792
# _________________________________________________________________

# %% [markdown]
# When untrained, the generator will produce garbage output. Although post training, we expect it to paint portraits.

# %%
random_arr = tf.random.normal([1,config.latent_dim])
random_img = generator(random_arr,training=False)
plt.imshow(random_img[0,:,:,0])

# %% [markdown]
# # Discriminator
#
# Generator's alter ego, the discriminator accepts an input image and identifies whether it's a real portrait. It consists of multiple convolutional blocks followed by a dense layer and functions like a typical CNN classfier. The final output is a score assgined based on whether the input seems real.

# %%
def conv_block(inp,activation,**kwargs):
    x = Conv2D(**kwargs)(inp)
    x = BatchNormalization()(x)
    x = activation(x)
    x = Dropout(config.dropout)(x)
    return x

# %%
inp_img = Input((config.img_size,config.img_size,3))
for i in range(len(config.discrim_arch)):
    layer = config.discrim_arch[i]
    dic = {'filters': layer[0], 'kernel_size': layer[1], 'strides': layer[2], 
           'padding': layer[3]}
    if i ==0:
        conv = conv_block(inp_img,activation=LeakyReLU(alpha=0.2),**dic)
    else:
        conv = conv_block(conv,activation=LeakyReLU(alpha=0.2),**dic)
fl = Flatten()(conv)
dense = Dense(1,activation='sigmoid')(fl)
discriminator = Model(inputs=inp_img,outputs=dense)
discriminator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 512)         2048
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 8, 8, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8, 8, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 32769
# =================================================================
# Total params: 1,605,313
# Trainable params: 1,603,329
# Non-trainable params: 1,984
# _________________________________________________________________

# %% [markdown]
# As the discriminator is unchanged, it verdicts that there's a 50% chance the garbage ouput is a real portrait. Once trained, it'll give better judgements.

# %%
#for the random image generated
reality_score = discriminator(random_img)
print (reality_score)
# Out:
# tf.Tensor([[0.49734372]], shape=(1, 1), dtype=float32)

# %% [markdown]
# # GAN Training
#
# GAN is the combination of the above defined generator and discriminator. The two are trained in isolation
# Here's the training loop
#
# ### Discriminator training
# 1. Generator creates fake images from a random array of specified latent dimensions
# 2. The fake images are labelled as 0, while the real ones as 1
# 3. The two sets are combined and passed into the discriminator
# 4. Using the labels, the discriminator learns to differentiate b/w real and fake images
#
# ### Generator training
# 1. Generator again creates fake images from a random array of specified latent dimensions
# 2. These fake images are labelled as 1 to confuse the discriminator
# 3. The fake images are passed to the discriminator which judges how whether the images are close to reality
# 4. Based on the output scores, gradients are created to update generator weights to create better images and outplay the discriminator
#
# During generator training phase, the discriminator's weights aren't updated and vice versa. This training loop continues for a number of epochs. Ideally, the GAN network is trained when the discrimnator gives an ouput of 0.5 regardless of the input image class. Basically, the quality of generated images improve to a point where the discriminator can't differentiate them from real images. However, due to a variety of reasons, this convergence is rarely, if ever, achieved.

# %%
class GAN(tf.keras.Model):
    def __init__(self, discriminator, generator, latent_dim):
        super(GAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim

    def compile(self, discr_optimizer, genr_optimizer, loss):
        super(GAN, self).compile()
        self.discr_optimizer = discr_optimizer
        self.genr_optimizer = genr_optimizer
        self.loss = loss
        self.discr_loss = tf.keras.metrics.Mean(name="discr_loss")
        self.genr_loss = tf.keras.metrics.Mean(name="genr_loss")

    @property
    def metrics(self):
        return [self.discr_loss, self.genr_loss]

    def train_step(self, real_portraits):
        batch_size = tf.shape(real_portraits)[0]
        #Generate a random array for generator to generate images
        x_fake = tf.random.normal(shape=(batch_size, self.latent_dim))
        #Generate fake images
        fake_portraits = self.generator(x_fake)
        # Jumble fake and real portraits to train discriminator
        portraits = tf.concat([real_portraits, fake_portraits], axis=0)
        # Assign labels as 1 and 0 for real and fake portraits
        labels = tf.concat([tf.ones((batch_size, 1)), tf.zeros((batch_size, 1))], axis=0)
        # Add random noise to the labels
        labels += 0.05 * tf.random.uniform(tf.shape(labels))
        # Discriminator training
        with tf.GradientTape() as tape:
            scores = self.discriminator(portraits)
            d_loss = self.loss(labels, scores)
        grads = tape.gradient(d_loss, self.discriminator.trainable_weights)
        self.discr_optimizer.apply_gradients(zip(grads, self.discriminator.trainable_weights))

        #Generate a random array for generator to generate images
        x_fake = tf.random.normal(shape=(batch_size, self.latent_dim))

        #Assign lables as 1 to confuse discriminator
        labels = tf.ones((batch_size, 1))

        # Train the generator while not updating the discriminator
        with tf.GradientTape() as tape:
            scores = self.discriminator(self.generator(x_fake))
            g_loss = self.loss(labels, scores)
        grads = tape.gradient(g_loss, self.generator.trainable_weights)
        self.genr_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights))

        # Update metrics
        self.discr_loss.update_state(d_loss)
        self.genr_loss.update_state(g_loss)
        return {"discriminator_loss": self.discr_loss.result(), "generator_loss": self.genr_loss.result()}

# %% [markdown]
# Below, is a custom training loop for the GAN network. I've used keras subclassing to create the GAN network and train it. Keras subclassing provides incredible flexibility using which, one can build their own training methodologies.

# %%
#The optimizers for Generator and Discriminator
discriminator_opt = tf.keras.optimizers.Adam(config.discriminator_lr,beta_1=config.beta)
generator_opt = tf.keras.optimizers.Adam(config.generator_lr,beta_1=config.beta)
loss = tf.keras.losses.BinaryCrossentropy()
model = GAN(discriminator, generator, config.latent_dim)
model.compile(discriminator_opt, generator_opt, loss)

history = model.fit(portraits, epochs=config.epochs)
# Out:
# Epoch 1/150
# 129/129 [==============================] - 47s 331ms/step - discriminator_loss: 0.6712 - generator_loss: 0.7196
# Epoch 2/150
# 129/129 [==============================] - 32s 237ms/step - discriminator_loss: 0.6410 - generator_loss: 0.7140
# Epoch 3/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.6197 - generator_loss: 0.7744
# Epoch 4/150
# 129/129 [==============================] - 33s 238ms/step - discriminator_loss: 0.6216 - generator_loss: 0.7406
# Epoch 5/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.7013 - generator_loss: 0.6957
# Epoch 6/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.3478 - generator_loss: 1.0728
# Epoch 7/150
# 129/129 [==============================] - 33s 238ms/step - discriminator_loss: 0.5289 - generator_loss: 0.8981
# Epoch 8/150
# 129/129 [==============================] - 34s 246ms/step - discriminator_loss: 0.6368 - generator_loss: 0.8684
# Epoch 9/150
# 129/129 [==============================] - 33s 238ms/step - discriminator_loss: 0.5760 - generator_loss: 0.8035
# Epoch 10/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.6503 - generator_loss: 0.8258
# Epoch 11/150
# 129/129 [==============================] - 32s 233ms/step - discriminator_loss: 0.7145 - generator_loss: 0.7302
# Epoch 12/150
# 129/129 [==============================] - 32s 233ms/step - discriminator_loss: 0.5909 - generator_loss: 0.6918
# Epoch 13/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.6061 - generator_loss: 0.8497
# Epoch 14/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.5482 - generator_loss: 0.8212
# Epoch 15/150
# 129/129 [==============================] - 33s 240ms/step - discriminator_loss: 0.3457 - generator_loss: 1.4458
# Epoch 16/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.5138 - generator_loss: 0.8918
# Epoch 17/150
# 129/129 [==============================] - 33s 238ms/step - discriminator_loss: 0.4170 - generator_loss: 1.1151
# Epoch 18/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.4916 - generator_loss: 0.9825
# Epoch 19/150
# 129/129 [==============================] - 33s 234ms/step - discriminator_loss: 0.5299 - generator_loss: 0.9443
# Epoch 20/150
# 129/129 [==============================] - 33s 238ms/step - discriminator_loss: 0.5471 - generator_loss: 0.9411
# Epoch 21/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.4220 - generator_loss: 1.2716
# Epoch 22/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.4562 - generator_loss: 1.1530
# Epoch 23/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.4274 - generator_loss: 1.0722
# Epoch 24/150
# 129/129 [==============================] - 33s 237ms/step - discriminator_loss: 0.4339 - generator_loss: 1.1516
# Epoch 25/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.4208 - generator_loss: 1.3454
# Epoch 26/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.4798 - generator_loss: 1.1023
# Epoch 27/150
# 129/129 [==============================] - 32s 232ms/step - discriminator_loss: 0.3917 - generator_loss: 1.1746
# Epoch 28/150
# 129/129 [==============================] - 33s 238ms/step - discriminator_loss: 0.4039 - generator_loss: 1.1142
# Epoch 29/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.4638 - generator_loss: 1.1527
# Epoch 30/150
# 129/129 [==============================] - 32s 229ms/step - discriminator_loss: 0.4883 - generator_loss: 1.3118
# Epoch 31/150
# 129/129 [==============================] - 32s 233ms/step - discriminator_loss: 0.4708 - generator_loss: 1.5130
# Epoch 32/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.4179 - generator_loss: 1.7636
# Epoch 33/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.4904 - generator_loss: 1.2383
# Epoch 34/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.4573 - generator_loss: 1.0130
# Epoch 35/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.4420 - generator_loss: 1.2416
# Epoch 36/150
# 129/129 [==============================] - 33s 239ms/step - discriminator_loss: 0.4382 - generator_loss: 1.3560
# Epoch 37/150
# 129/129 [==============================] - 32s 237ms/step - discriminator_loss: 0.5664 - generator_loss: 0.8949
# Epoch 38/150
# 129/129 [==============================] - 32s 237ms/step - discriminator_loss: 0.4806 - generator_loss: 1.1054
# Epoch 39/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.4846 - generator_loss: 1.0459
# Epoch 40/150
# 129/129 [==============================] - 33s 235ms/step - discriminator_loss: 0.5315 - generator_loss: 0.8717
# Epoch 41/150
# 129/129 [==============================] - 32s 237ms/step - discriminator_loss: 0.6124 - generator_loss: 0.9695
# Epoch 42/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.6482 - generator_loss: 0.7113
# Epoch 43/150
# 129/129 [==============================] - 32s 233ms/step - discriminator_loss: 0.5551 - generator_loss: 0.9307
# Epoch 44/150
# 129/129 [==============================] - 33s 239ms/step - discriminator_loss: 0.5295 - generator_loss: 0.9111
# Epoch 45/150
# 129/129 [==============================] - 33s 237ms/step - discriminator_loss: 0.5395 - generator_loss: 1.1793
# Epoch 46/150
# 129/129 [==============================] - 32s 233ms/step - discriminator_loss: 0.6530 - generator_loss: 0.7463
# Epoch 47/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.6972 - generator_loss: 0.7940
# Epoch 48/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.6869 - generator_loss: 0.7615
# Epoch 49/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.6097 - generator_loss: 0.8618
# Epoch 50/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.6144 - generator_loss: 0.9097
# Epoch 51/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.6278 - generator_loss: 0.8435
# Epoch 52/150
# 129/129 [==============================] - 34s 245ms/step - discriminator_loss: 0.6313 - generator_loss: 0.8082
# Epoch 53/150
# 129/129 [==============================] - 33s 237ms/step - discriminator_loss: 0.6470 - generator_loss: 0.7605
# Epoch 54/150
# 129/129 [==============================] - 32s 237ms/step - discriminator_loss: 0.6309 - generator_loss: 0.8122
# Epoch 55/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.6417 - generator_loss: 0.7822
# Epoch 56/150
# 129/129 [==============================] - 32s 230ms/step - discriminator_loss: 0.6119 - generator_loss: 1.2831
# Epoch 57/150
# 129/129 [==============================] - 32s 237ms/step - discriminator_loss: 0.6600 - generator_loss: 0.7656
# Epoch 58/150
# 129/129 [==============================] - 33s 237ms/step - discriminator_loss: 0.6323 - generator_loss: 1.3158
# Epoch 59/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.6048 - generator_loss: 0.7817
# Epoch 60/150
# 129/129 [==============================] - 33s 236ms/step - discriminator_loss: 0.5571 - generator_loss: 0.8640
# Epoch 61/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.5505 - generator_loss: 0.8977
# Epoch 62/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.5540 - generator_loss: 0.9735
# Epoch 63/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.5732 - generator_loss: 0.8242
# Epoch 64/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.4897 - generator_loss: 1.4331
# Epoch 65/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.5721 - generator_loss: 0.9511
# Epoch 66/150
# 129/129 [==============================] - 32s 233ms/step - discriminator_loss: 0.5999 - generator_loss: 0.8354
# Epoch 67/150
# 129/129 [==============================] - 32s 237ms/step - discriminator_loss: 0.5377 - generator_loss: 0.9019
# Epoch 68/150
# 129/129 [==============================] - 32s 237ms/step - discriminator_loss: 0.6057 - generator_loss: 0.8809s - discriminator_loss: 0.6058 - generator_loss: 0.
# Epoch 69/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.5278 - generator_loss: 1.0339
# Epoch 70/150
# 129/129 [==============================] - 33s 237ms/step - discriminator_loss: 0.6048 - generator_loss: 0.9260
# Epoch 71/150
# 129/129 [==============================] - 33s 239ms/step - discriminator_loss: 0.5572 - generator_loss: 0.8373
# Epoch 72/150
# 129/129 [==============================] - 33s 236ms/step - discriminator_loss: 0.4955 - generator_loss: 1.0160
# Epoch 73/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.5320 - generator_loss: 1.0523
# Epoch 74/150
# 129/129 [==============================] - 33s 237ms/step - discriminator_loss: 0.4929 - generator_loss: 1.2530
# Epoch 75/150
# 129/129 [==============================] - 33s 238ms/step - discriminator_loss: 0.4842 - generator_loss: 1.3955
# Epoch 76/150
# 129/129 [==============================] - 33s 239ms/step - discriminator_loss: 0.5662 - generator_loss: 0.8598
# Epoch 77/150
# 129/129 [==============================] - 33s 236ms/step - discriminator_loss: 0.4891 - generator_loss: 0.9691
# Epoch 78/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.5834 - generator_loss: 0.8491
# Epoch 79/150
# 129/129 [==============================] - 33s 240ms/step - discriminator_loss: 0.5348 - generator_loss: 0.9710
# Epoch 80/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.5792 - generator_loss: 1.2419
# Epoch 81/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.4583 - generator_loss: 1.1108
# Epoch 82/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.3970 - generator_loss: 1.2061
# Epoch 83/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.6807 - generator_loss: 1.3555
# Epoch 84/150
# 129/129 [==============================] - 32s 232ms/step - discriminator_loss: 0.4950 - generator_loss: 1.2936
# Epoch 85/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.5959 - generator_loss: 0.8244
# Epoch 86/150
# 129/129 [==============================] - 31s 227ms/step - discriminator_loss: 0.4690 - generator_loss: 1.1561
# Epoch 87/150
# 129/129 [==============================] - 32s 233ms/step - discriminator_loss: 0.5083 - generator_loss: 1.0479
# Epoch 88/150
# 129/129 [==============================] - 32s 233ms/step - discriminator_loss: 0.5075 - generator_loss: 0.9835
# Epoch 89/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.4889 - generator_loss: 1.0797
# Epoch 90/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.4602 - generator_loss: 1.1688
# Epoch 91/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.5415 - generator_loss: 0.8581
# Epoch 92/150
# 129/129 [==============================] - 32s 233ms/step - discriminator_loss: 0.6007 - generator_loss: 0.8483
# Epoch 93/150
# 129/129 [==============================] - 32s 237ms/step - discriminator_loss: 0.5089 - generator_loss: 1.0069
# Epoch 94/150
# 129/129 [==============================] - 32s 237ms/step - discriminator_loss: 0.5768 - generator_loss: 0.8718
# Epoch 95/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.4944 - generator_loss: 0.9609
# Epoch 96/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.5433 - generator_loss: 1.0825
# Epoch 97/150
# 129/129 [==============================] - 33s 240ms/step - discriminator_loss: 0.5161 - generator_loss: 1.0794
# Epoch 98/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.5967 - generator_loss: 0.9279
# Epoch 99/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.5742 - generator_loss: 1.2125
# Epoch 100/150
# 129/129 [==============================] - 33s 240ms/step - discriminator_loss: 0.5530 - generator_loss: 0.9348
# Epoch 101/150
# 129/129 [==============================] - 33s 237ms/step - discriminator_loss: 0.5605 - generator_loss: 0.9284
# Epoch 102/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.6534 - generator_loss: 0.8160
# Epoch 103/150
# 129/129 [==============================] - 33s 238ms/step - discriminator_loss: 0.5245 - generator_loss: 0.9469
# Epoch 104/150
# 129/129 [==============================] - 32s 233ms/step - discriminator_loss: 0.5564 - generator_loss: 0.9229
# Epoch 105/150
# 129/129 [==============================] - 33s 237ms/step - discriminator_loss: 0.5602 - generator_loss: 1.1425
# Epoch 106/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.5552 - generator_loss: 0.9195
# Epoch 107/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.5408 - generator_loss: 0.8564
# Epoch 108/150
# 129/129 [==============================] - 33s 239ms/step - discriminator_loss: 0.5342 - generator_loss: 1.1164
# Epoch 109/150
# 129/129 [==============================] - 33s 238ms/step - discriminator_loss: 0.4360 - generator_loss: 1.6959
# Epoch 110/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.5274 - generator_loss: 1.0893
# Epoch 111/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.6354 - generator_loss: 0.8191
# Epoch 112/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.5718 - generator_loss: 0.8131
# Epoch 113/150
# 129/129 [==============================] - 33s 238ms/step - discriminator_loss: 0.5124 - generator_loss: 0.9054
# Epoch 114/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.5979 - generator_loss: 0.9976
# Epoch 115/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.6050 - generator_loss: 0.8752
# Epoch 116/150
# 129/129 [==============================] - 33s 238ms/step - discriminator_loss: 0.5330 - generator_loss: 0.9926
# Epoch 117/150
# 129/129 [==============================] - 33s 238ms/step - discriminator_loss: 0.6326 - generator_loss: 0.8011
# Epoch 118/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.5328 - generator_loss: 0.9445
# Epoch 119/150
# 129/129 [==============================] - 33s 237ms/step - discriminator_loss: 0.5504 - generator_loss: 1.3715
# Epoch 120/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.5518 - generator_loss: 1.4170s - discriminator_l
# Epoch 121/150
# 129/129 [==============================] - 33s 239ms/step - discriminator_loss: 0.5284 - generator_loss: 1.0907
# Epoch 122/150
# 129/129 [==============================] - 32s 232ms/step - discriminator_loss: 0.5982 - generator_loss: 1.1044
# Epoch 123/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.5544 - generator_loss: 0.8919
# Epoch 124/150
# 129/129 [==============================] - 33s 238ms/step - discriminator_loss: 0.5519 - generator_loss: 0.8638
# Epoch 125/150
# 129/129 [==============================] - 33s 240ms/step - discriminator_loss: 0.5098 - generator_loss: 1.0837
# Epoch 126/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.4679 - generator_loss: 1.0062
# Epoch 127/150
# 129/129 [==============================] - 33s 238ms/step - discriminator_loss: 0.5596 - generator_loss: 1.0203
# Epoch 128/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.5154 - generator_loss: 1.2600
# Epoch 129/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.5010 - generator_loss: 1.0983
# Epoch 130/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.5911 - generator_loss: 0.9577
# Epoch 131/150
# 129/129 [==============================] - 33s 238ms/step - discriminator_loss: 0.5356 - generator_loss: 0.9113
# Epoch 132/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.5631 - generator_loss: 0.9629
# Epoch 133/150
# 129/129 [==============================] - 33s 237ms/step - discriminator_loss: 0.5979 - generator_loss: 0.8880
# Epoch 134/150
# 129/129 [==============================] - 32s 233ms/step - discriminator_loss: 0.6296 - generator_loss: 0.7984
# Epoch 135/150
# 129/129 [==============================] - 33s 237ms/step - discriminator_loss: 0.5072 - generator_loss: 0.9823
# Epoch 136/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.3547 - generator_loss: 1.2975
# Epoch 137/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.5012 - generator_loss: 1.0989
# Epoch 138/150
# 129/129 [==============================] - 32s 232ms/step - discriminator_loss: 0.5602 - generator_loss: 0.8719
# Epoch 139/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.4964 - generator_loss: 1.0133
# Epoch 140/150
# 129/129 [==============================] - 33s 239ms/step - discriminator_loss: 0.5706 - generator_loss: 1.2739s - discr
# Epoch 141/150
# 129/129 [==============================] - 32s 237ms/step - discriminator_loss: 0.5612 - generator_loss: 1.1814
# Epoch 142/150
# 129/129 [==============================] - 32s 232ms/step - discriminator_loss: 0.6057 - generator_loss: 0.8115
# Epoch 143/150
# 129/129 [==============================] - 32s 237ms/step - discriminator_loss: 0.4692 - generator_loss: 1.0242
# Epoch 144/150
# 129/129 [==============================] - 32s 233ms/step - discriminator_loss: 0.5571 - generator_loss: 1.0243
# Epoch 145/150
# 129/129 [==============================] - 32s 236ms/step - discriminator_loss: 0.4761 - generator_loss: 1.1688
# Epoch 146/150
# 129/129 [==============================] - 33s 235ms/step - discriminator_loss: 0.3397 - generator_loss: 1.4905
# Epoch 147/150
# 129/129 [==============================] - 33s 238ms/step - discriminator_loss: 0.3899 - generator_loss: 1.2808
# Epoch 148/150
# 129/129 [==============================] - 32s 235ms/step - discriminator_loss: 0.5816 - generator_loss: 0.9847
# Epoch 149/150
# 129/129 [==============================] - 32s 232ms/step - discriminator_loss: 0.5952 - generator_loss: 0.8629
# Epoch 150/150
# 129/129 [==============================] - 32s 234ms/step - discriminator_loss: 0.5231 - generator_loss: 0.9614

# %% [markdown]
# # Evaluation
#
# There are two chief problems associated with GAN training
#
# 1. Loss convergence - As the generator and discriminator attempt to outplay each other, the loss seldom converges. In the image plotted below, the generator loss shows a mildly erratic behaviour with no signs of convergence. Inability to achieve convergence leads to poor quality of generated images.
#
# 2. Mode collapse - After each iteration of discriminator training, the generator updates its weights to fool that particular discriminator. Now, if the discriminator gets stuck in a local minima, and the generator produces an output that fools it, we enter mode collapse. Since the discriminator stops improving, the generator also loses the incentive to search for alternative outputs and starts producing the same output (single/subset) in each iteration.

# %%
history_df = pd.DataFrame(history.history)
fig = plt.figure(figsize=(15,4))
plt.plot(history_df['discriminator_loss'],label='discriminator_loss')
plt.plot(history_df['generator_loss'],label='generator_loss')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()
plt.show()

# %% [markdown]
# From the images below, it's clearly evident that the GAN has entered mode collapse. When working with small amount of images, one can identify mode collapse by plotting outputs. However, it's desirable to have measures to quantify mode collapse. We'll use k-means clustering to come with a metric.

# %%
f,ax = plt.subplots(3,5,figsize=(15,10))
ax = ax.flatten()
arr = tf.random.normal(shape=(15, config.latent_dim))
generated_portraits = generator(arr)
for i in range(15):
    ax[i].imshow(generated_portraits[i])

# %%
from sklearn.cluster import KMeans

# %%
#Flatten images from train loader
#Cluster
#Find optimal classes
#Cluster generated images
#Compute NDB score

# %% [markdown]
# The first step is to cluster training images to find the optimal number of classes. This might not make sense on a qualitative level since all our images are portraits. Nevertheless, I expect the algorithm to identify subtle similarities amongst the portraits and create appropriate clusters. We'll iterate through our tf dataloader to create an array of all training images. We have rgb images of shape (64,64). To reduce dimensions, we'll average the arrays along the last axis to convert them to grayscale. Note that the actual formula for converting to grayscale is different. Refer this [link](https://e2eml.school/convert_rgb_to_grayscale.html) for more information. We can further shrink the dimensions using autoencoders/PCA, but I'll not for now. Finally, for clustering, we'll also flatten the images

# %%
images = []
training = tf.keras.preprocessing.image_dataset_from_directory(config.img_dir,label_mode=None ,image_size=(config.img_size,config.img_size), batch_size=1).map(lambda x: x / 255.0)
for i,batch in enumerate(training):
    if i == len(training):
        break
    else:
        images.append(np.array(batch[0]))
# Out:
# Found 4117 files belonging to 1 classes.

# %%
images = np.asarray(images)
images = np.mean(images,axis=3)
images = images.reshape((images.shape[0],-1))

# %% [markdown]
# To save computational time, I'll only use the first 100 images to create clusters

# %%
elbow_scores=[]
for c in range(4,10):
    kmeans = KMeans(c)
    kmeans.fit(images[:100])
    elbow_scores.append(kmeans.inertia_)

# %% [markdown]
# From the elbow score, it seems that we should use more clusters. This is expected as all images are of the same class(portraits) and hence the differences are subtle. Further reduction in image dimensionality might help create better clusters. However, I see a minor kink at 8 clusters, and for illustrative purposes, stick to it.

# %%
plt.plot(range(4,10),elbow_scores)
plt.xlabel('Number of Clusters')
plt.title('Elbow Score')
plt.show()

# %%
kmeans=KMeans(8)
train_classes=kmeans.fit_predict(images[:100])

# %% [markdown]
# Now,we'll generate 100 images from the generator, and see which clusters they fall into.

# %%
arr = tf.random.normal(shape=(100, config.latent_dim))
generated_portraits = generator(arr)

# %%
generated_portraits = np.array(generated_portraits).mean(axis=3).reshape((generated_portraits.shape[0],-1))

# %% [markdown]
# As, you can see all the generated portraits belong to the same cluster. Now, we'll expand this idea to create a more concrete statstical test.

# %%
generated_classes = kmeans.predict(generated_portraits)

# %% [markdown]
# # NDB Score
#
# The ideal GAN should learn a probability distribution that closely mimics the training data distribution. This is quantified using [NDB score](https://arxiv.org/abs/1805.12462). Here's how its computed:
#
# 1. Cluster the training data (t samples) into 'n' bins (Like we have clustered the portraits into 8 bins)
# 2. Generate (g samples) of images
# 3. Predict the cluster(bin) of each generated image
# 4. For each bin do the following test:
#
#     4.1 Compute the proportions of training and generated samples in that bin
#
#     4.2 Divide their difference by the standard error SE which is calculated as shown below. Here 'p' and 'q' are used to refer training and generated data, and 'P' is the pooled sample proportion
#
# ![image.png](attachment:ab7561e5-6b5a-4811-b0ec-73bb6df593b0.png)
#
#     4.3 If the p-value corresponding to the z-score is less than a threshold, the bin is deemed statistically different
#
# 5. Divide the number of statistically different bins by the number of bins. This'll give a number b/w 0 and 1 quantifying the difference between the real and learned distributions.
# 6. If '5' is greater than a set threshold, the GAN is deemed to have encountered mode collapse.
#
# Please refer these links for more details:
# 1. https://www.google.com/search?q=ndb+score+gan&oq=ndb+&aqs=chrome.0.69i59j69i57j46i199i465i512j46i175i199i512j0i512j0i433i512j0i512j69i60.1083j0j7&sourceid=chrome&ie=UTF-8
#
# 2. https://arxiv.org/abs/1805.12462

# %%
def ndb_score(training_data_classes,generated_data_classes,num_classes,z_threshold):
    ndb = []
    NT = len(training_data_classes)
    NG = len(generated_data_classes)
    for i in range(num_classes):
        nt = np.sum(training_data_classes==i)
        pt = nt/len(training_data_classes) #training data proportion for bin
        ng = np.sum(generated_data_classes==i)
        pg = ng/len(generated_data_classes) #generated data proportion for bin
        P = (nt+ng)/(NT+NG)
        SE = (P*(1-P)*((1/NT)+(1/NG)))**0.5
        if abs((pt-pg)/SE) > z_threshold:
            ndb.append(i)
    print(f"Statisticall different classes:{ndb}")
    print(f"ndb score: {len(ndb)/num_classes}")

# %%
ndb_score(train_classes,generated_classes,8,1.96)
# Out:
# Statisticall different classes:[0, 1, 2, 4, 5, 7]
# ndb score: 0.75

# %% [markdown]
# For our case, we have a high ndb score indicative of mode collapse.

# %% [markdown]
# # CONCLUSION
#
# NDB score could be an extremely handy metric to measure gan performance when working with big data. Here, like the paper, we have only used k-means clustering to create bins. However, as discussed, one could further reduce image dimensionality by running PCA on images or creating image feature vectors using autoencoders or intermediate CNN layers. Tuning hyperparamters could be one way to prevent mode collapse. But we have other options too. One could use a different loss function, or use unrolled GANs. I'll try to create a notebook on improving GAN performance next.
#
# References:
#
# 1. https://www.google.com/search?q=ndb+score+gan&oq=ndb+&aqs=chrome.0.69i59j69i57j46i199i465i512j46i175i199i512j0i512j0i433i512j0i512j69i60.1083j0j7&sourceid=chrome&ie=UTF-8
#
# 2. https://arxiv.org/abs/1805.12462
# 3. https://www.kaggle.com/code/karnikakapoor/art-by-gan
